# %%
#pandas
import pandas as pd
import os

# %%
# Get the current working directory
current_directory = os.getcwd()

# Print the current working directory
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/snehaanand

# %%
# Set a new working directory
new_directory = '/Users/snehaanand/documents'
os.chdir(new_directory)

# Print the new working directory
print("New Working Directory:", os.getcwd())
# Out:
# New Working Directory: /Users/snehaanand/Documents

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#check the number of rows and columns in the dataset
df.shape
# Out:
# (1338, 7)

# %%
#check coulumn name
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#check count
print (f'age: {df.age.count()}')
print (f'bmi: {df.bmi.count()}')
print (f'sex: {df.sex.count()}')
print (f'children: {df.children.count()}')
print (f'smoker: {df.smoker.count()}')
print (f'region: {df.region.count()}')
print (f'charges: {df.charges.count()}')
# Out:
# age: 1338
# bmi: 1338
# sex: 1338
# children: 1338
# smoker: 1338
# region: 1338
# charges: 1338

# %%
#check unique values
print (f'age: {df.age.nunique()}')
print (f'bmi: {df.bmi.nunique()}')
print (f'sex: {df.sex.nunique()}')
print (f'children: {df.children.nunique()}')
print (f'smoker: {df.smoker.nunique()}')
print (f'region: {df.region.nunique()}')
print (f'charges: {df.charges.nunique()}')
# Out:
# age: 47
# bmi: 548
# sex: 2
# children: 6
# smoker: 2
# region: 4
# charges: 1337

# %%
print (f'age: {df.age.dtype}')
print (f'bmi: {df.bmi.dtype}')
print (f'sex: {df.sex.dtype}')
print (f'children: {df.children.dtype}')
print (f'smoker: {df.smoker.dtype}')
print (f'region: {df.region.dtype}')
print (f'charges: {df.charges.dtype}')
# Out:
# age: int64
# bmi: float64
# sex: object
# children: int64
# smoker: object
# region: object
# charges: float64

# %%
print (f'age: {pd.api.types.is_numeric_dtype(df.age)}')
print (f'bmi: {pd.api.types.is_numeric_dtype(df.bmi)}')
print (f'sex: {pd.api.types.is_numeric_dtype(df.sex)}')
print (f'children: {pd.api.types.is_numeric_dtype(df.children)}')
print (f'smoker: {pd.api.types.is_numeric_dtype(df.smoker)}')
print (f'region: {pd.api.types.is_numeric_dtype (df.region)}')
print (f'charges: {pd.api.types.is_numeric_dtype(df.charges)}')
# Out:
# age: True
# bmi: True
# sex: False
# children: True
# smoker: False
# region: False
# charges: True

# %%
print (f'age: {df.age.isnull().sum()}')
print (f'bmi: {df.bmi.isnull().sum()}')
print (f'sex: {df.sex.isnull().sum()}')
print (f'children: {df.children.isnull().sum()}')
print (f'smoker: {df.smoker.isnull().sum()}')
print (f'region: {df.region.isnull().sum()}')
print (f'charges: {df.charges.isnull().sum()}')
# Out:
# age: 0
# bmi: 0
# sex: 0
# children: 0
# smoker: 0
# region: 0
# charges: 0

# %%
import numpy as np

# %%
#statistics for charges
#lquantile - lower quantile, mquantile - median quantile, hquantile - higher quantile
print (f'min: {df.charges.min()}')
print (f'lquantile: {df.charges.quantile(.25)}')
print (f'mquantile: {df.charges.quantile(.50)}')
print (f'hquantile: {df.charges.quantile(.75)}')
print (f'max: {df.charges.max()}')
print (f'mean: {df.charges.mean()}')
print (f'median: {df.charges.median()}')
print (f'median: {df.charges.mode().values[0]}')
# Out:
# min: 1121.8739
# lquantile: 4740.28715
# mquantile: 9382.033
# hquantile: 16639.912515
# max: 63770.42801
# mean: 13270.422265141257
# median: 9382.033
# median: 1639.5631

# %%
#standard deviation
df.charges.std()
# Out:
# 12110.011236693996

# %%
#skewness and kurtosis
from scipy.stats import kurtosis, skew

# %%
print(skew(df.charges, bias = False))
print(kurtosis(df.charges, bias = False))
# Out:
# 1.5158796580240383
# 1.6062986532967916

# %%
#alternatively
print(df.charges.skew()) #positive, distribution skewed to the right
print(df.charges.kurt()) #platykurtic
# Out:
# 1.5158796580240388
# 1.6062986532967907

# %%
#correlation
import numpy as np

# %%
#example
height = [60, 62, 65, 68, 70, 74]
weight = [140, 138, 150, 166, 190, 250]
np.corrcoef(height, weight)[0][1]
# Out:
# 0.9298974521408027

# %%
#insurance dataset
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data_type = df.dtypes
data_type
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
#change column types
df['bmi'] = df['bmi'].astype('int64')
df['charges'] = df['charges'].astype('int64')
df['smoker'] = df['smoker'].astype('object')
df['sex'] = df['sex'].astype('object')
df['region'] = df['region'].astype('object')

# %%
df.dtypes
# Out:
# age          int64
# sex         object
# bmi          int64
# children     int64
# smoker      object
# region      object
# charges      int64
# dtype: object

# %%
# Select only columns with int64 data type
int64_columns = df.select_dtypes(include='int64')

# Calculate the correlation matrix
correlation_matrix = int64_columns.corr()
correlation_matrix
# Out:
#                age       bmi  children   charges
# age       1.000000  0.108437  0.042469  0.299009
# bmi       0.108437  1.000000  0.011097  0.196188
# children  0.042469  0.011097  1.000000  0.067999
# charges   0.299009  0.196188  0.067999  1.000000

# %%
df.charges.corr(df.bmi)
# Out:
# 0.1961884083143169

# %%
from scipy import stats

# %%
#pearson correlation 
corr = stats.pearsonr(df.charges, df.age)
corr #p value significant
# Out:
# PearsonRResult(statistic=0.2990086877278488, pvalue=4.8856256198049225e-29)

# %%
r, p = stats.pearsonr(df.charges, df.age)
print(round(r,4))
print(round(p,29))
# Out:
# 0.299
# 5.0000000000000004e-29

# %%
# Select only columns with int64 data type
int64_columns = df.select_dtypes(include='int64')

# Create an empty DataFrame to store correlation results
corr_df = pd.DataFrame(columns=['r', 'p'])

# Iterate over columns in int64_columns
for col in int64_columns.columns:
    # Calculate Pearson correlation and p-value
    r, p = stats.pearsonr(df['charges'], int64_columns[col])
    corr_df.loc[col] = [round(r, 3), round(p, 3)]

# Display the correlation DataFrame
print(corr_df)
# Out:
#               r      p
# age       0.299  0.000
# bmi       0.196  0.000
# children  0.068  0.013
# charges   1.000  0.000

# %%
# Select only int64 columns excluding 'charges'
int64_columns = df.select_dtypes(include='int64').drop(columns=['charges'])

# Create an empty DataFrame to store correlation results
corr_df = pd.DataFrame(columns=['r', 'p'])

# Iterate over columns in int64_columns
for col in int64_columns.columns:
    # Calculate Pearson correlation and p-value
    r, p = stats.pearsonr(df['charges'], int64_columns[col])
    corr_df.loc[col] = [round(r, 3), round(p, 3)]

# Display the correlation DataFrame
print(corr_df)
# Out:
#               r      p
# age       0.299  0.000
# bmi       0.196  0.000
# children  0.068  0.013

# %%
import matplotlib.pyplot as plt

# %%
#scatter plot
plt.scatter(df.age, df.charges)
plt.title('Insurance age versus charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

#insurance charges slightly increasing with age

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# %matplotlib inline

#scatter plot split between smokers and non smokers
df_smoker = df[df['smoker'] == 'yes']
df_nonsmoker = df[df['smoker'] == 'no']

df.head
plt.scatter(df_smoker.age, df_smoker.charges, label = 'Smokers')
plt.scatter(df_nonsmoker.age, df_nonsmoker.charges, label = 'Non-Smokers')
plt.title('Insurance age versus charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#scatter plot split between smokers and non smokers (reduced sample size)
df_smoker_reduced = df_smoker.sample(50)
df_nonsmoker_reduced = df_nonsmoker.sample(50)

df.head
plt.scatter(df_smoker_reduced.age, df_smoker_reduced.charges, label = 'Smokers')
plt.scatter(df_nonsmoker_reduced.age, df_nonsmoker_reduced.charges, label = 'Non-Smokers')
plt.title('Insurance age versus charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))

# %%
#customising plots
df_smoker_reduced = df_smoker.sample(50)
df_nonsmoker_reduced = df_nonsmoker.sample(50)

df.head
plt.scatter(df_smoker_reduced.age, df_smoker_reduced.charges, label = 'Smokers', color = 'pink', marker = '^')
plt.scatter(df_nonsmoker_reduced.age, df_nonsmoker_reduced.charges, label = 'Non-Smokers', color = 'silver', marker = 'o')
plt.title('Insurance age versus charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.legend()
plt.show()
plt.figure(figsize=(10, 6))

# %%
from scipy import stats

# %%
m, b, r, p, err = stats.linregress(df.age, df.charges) # charges = 257.7 (age) + 3165 
print(m, b, r, p, err) # m - slope, b - intercept, r - correlation, p - pvalue
plt.scatter(df.age, df.charges)
plt.title('Insurance age versus charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()
# Out:
# 257.7226186668956 3165.885006063023 0.29900819333064776 4.886693331718281e-29 22.5023892867703

# %%
m, b, r, p, err = stats.linregress(df.age, df.charges) # charges = 257.7 (age) + 3165 
print(m, b, r, p, err) # m - slope, b - intercept, r - correlation, p - pvalue
x = range (10, df.age.max() + 2)
y = m*x + b
plt.plot(x,y, color = 'grey')
plt.scatter(df.age, df.charges)
plt.title('Insurance age versus charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()
# Out:
# 257.7226186668956 3165.885006063023 0.29900819333064776 4.886693331718281e-29 22.5023892867703

# %%
import statsmodels

# %%
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.diagnostic import het_white
from statsmodels.formula.api import ols


model = ols(formula = 'charges~age', data = df).fit()

white_test = het_white(model.resid, model.model.exog)
breuschpagan_test = het_breuschpagan(model.resid, model.model.exog)

output_df = pd.DataFrame(columns=['LM Stat', 'LM p', 'F stat', 'F stat p'])
output_df.loc['White'] = white_test
output_df.loc['Breusch-Pagan'] = breuschpagan_test

output_df
#residuals across all variables of X fairly consistent
# Out:
#                 LM Stat      LM p    F stat  F stat p
# White          0.002713  0.998645  0.001353  0.998648
# Breusch-Pagan  0.000413  0.983776  0.000413  0.983792

# %%
#flipping variables
model = ols(formula = 'age~charges', data = df).fit()

white_test = het_white(model.resid, model.model.exog)
breuschpagan_test = het_breuschpagan(model.resid, model.model.exog)

output_df = pd.DataFrame(columns=['LM Stat', 'LM p', 'F stat', 'F stat p'])
output_df.loc['White'] = white_test
output_df.loc['Breusch-Pagan'] = breuschpagan_test

output_df
#inconsistent spread of dots. having Y first important in the formula
# Out:
#                   LM Stat          LM p     F stat      F stat p
# White          113.205738  2.616293e-25  61.695937  2.358806e-26
# Breusch-Pagan   48.227283  3.795702e-12  49.955817  2.525670e-12

# %%
import seaborn as sns

sns.set(color_codes = True)
sns.jointplot(x = 'age', y = 'charges', data = df)
plt.show()

# %%
sns.set(color_codes = True)
sns.jointplot(x = 'age', y = 'charges', kind = 'hex', data = df)

#most dots at the bottom

# %%
sns.set_style("white")
sns.jointplot(x = 'age', y = 'charges', kind = 'hex', data = df)

# %%
#kernel density estimation
sns.jointplot(x = 'age', y = 'charges', kind = 'kde', data = df)
#smoothed lines indicate the flow of binned values

# %%
f, ax = plt.subplots(figsize=(8, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=False)
sns.kdeplot(x=df.age, y=df.charges, cmap=cmap, n_levels=60, shade=True)

plt.show()
# Out:
# /var/folders/l9/w_hvf95x16946fgqz61fz3g80000gn/T/ipykernel_1051/3155332404.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df.age, y=df.charges, cmap=cmap, n_levels=60, shade=True)

# %%
import statsmodels.api as sm

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#MLR OLS STATS MODLES

label = "charges"
y = df.charges
x = df[['age', 'bmi', 'children']].assign(const=1)
model = sm.OLS(y, x)
results = model.fit()
print(results.summary())

#these are non-standardized values so cannot compare the variables
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     60.69
# Date:                Fri, 01 Mar 2024   Prob (F-statistic):           8.80e-37
# Time:                        16:42:48   Log-Likelihood:                -14392.
# No. Observations:                1338   AIC:                         2.879e+04
# Df Residuals:                    1334   BIC:                         2.881e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age          239.9945     22.289     10.767      0.000     196.269     283.720
# ...

# %%
#predictions
df['predictions'] = results.fittedvalues
df

#predictions give us scored values based on the above regression model
#predictions not accurate because of low r squared value in the previous model
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#        predictions
# 0      6908.777533
# 1      9160.977061
# 2     12390.946918
# 3      8543.527095
# 4     10354.147396
# ...            ...
# ...

# %%
print(results.predict([19, 27.9, 0, 1]))
# Out:
# [6908.77753344]
